# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Reorganize dataset

# %% [markdown]
# ## Class 1

# %%
# Define paths for class 1 
good_images_dir = 'raw/Class1'
anomaly_images_dir = 'raw/Class1_def'
train_dir = 'differnet-master/DAGM_dataset/DAGM_class_1/train'
train_good_dir = os.path.join(train_dir, 'good')
test_dir = 'differnet-master/DAGM_dataset/DAGM_class_1/test'
test_anomaly_dir = os.path.join(test_dir, 'anomaly')
test_good_dir = os.path.join(test_dir, 'good')

# Create train and test directories if they don't exist
os.makedirs(train_good_dir, exist_ok=True)
os.makedirs(test_anomaly_dir, exist_ok=True)
os.makedirs(test_good_dir, exist_ok=True)

# %%
# List all images
def list_images(directory):
    return [os.path.join(directory, img) for img in os.listdir(directory)
            if os.path.isfile(os.path.join(directory, img)) and img.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]

good_images = list_images(good_images_dir)
anomaly_images = list_images(anomaly_images_dir)

# Ensure that there are images to split
if not good_images:
    raise ValueError(f"No images found in the good images directory: {good_images_dir}")
if not anomaly_images:
    raise ValueError(f"No images found in the anomaly images directory: {anomaly_images_dir}")

# %%
# Split only good images into training and test sets
good_train, good_test = train_test_split(good_images, test_size=0.2, random_state=42)

# Function to copy images to their respective directories
def copy_images(image_list, destination_dir):
    for img_path in image_list:
        shutil.copy(img_path, destination_dir)

# Copy good images to train and test directories
copy_images(good_train, train_good_dir)
copy_images(good_test, test_good_dir)

# Copy all anomaly images to test directory
copy_images(anomaly_images, test_anomaly_dir)

print("Train-test split and organization completed successfully.")
# Out:
# Train-test split and organization completed successfully.

# %%
# Function to count images in a directory
def count_images(directory):
    return len([img for img in os.listdir(directory)
                if os.path.isfile(os.path.join(directory, img)) and img.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))])

# Count images
train_good_count = count_images(train_good_dir)
test_good_count = count_images(test_good_dir)
test_anomaly_count = count_images(test_anomaly_dir)

# Print the counts
print(f"Number of good images in training directory: {train_good_count}")
print(f"Number of good images in testing directory: {test_good_count}")
print(f"Number of anomaly images in testing directory: {test_anomaly_count}")
# Out:
# Number of good images in training directory: 800
# Number of good images in testing directory: 200
# Number of anomaly images in testing directory: 150

# %% [markdown]
# ## Class 2

# %%
# Define paths for class 2
good_images_dir = 'raw/Class2'
anomaly_images_dir = 'raw/Class2_def'
train_dir = 'differnet-master/DAGM_dataset/DAGM_class_2/train'
train_good_dir = os.path.join(train_dir, 'good')
test_dir = 'differnet-master/DAGM_dataset/DAGM_class_2/test'
test_anomaly_dir = os.path.join(test_dir, 'anomaly')
test_good_dir = os.path.join(test_dir, 'good')

# Create train and test directories if they don't exist
os.makedirs(train_good_dir, exist_ok=True)
os.makedirs(test_anomaly_dir, exist_ok=True)
os.makedirs(test_good_dir, exist_ok=True)

# %%
# List all images
def list_images(directory):
    return [os.path.join(directory, img) for img in os.listdir(directory)
            if os.path.isfile(os.path.join(directory, img)) and img.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]

good_images = list_images(good_images_dir)
anomaly_images = list_images(anomaly_images_dir)

# Ensure that there are images to split
if not good_images:
    raise ValueError(f"No images found in the good images directory: {good_images_dir}")
if not anomaly_images:
    raise ValueError(f"No images found in the anomaly images directory: {anomaly_images_dir}")

# %%
# Split only good images into training and test sets
good_train, good_test = train_test_split(good_images, test_size=0.2, random_state=42)

# Function to copy images to their respective directories
def copy_images(image_list, destination_dir):
    for img_path in image_list:
        shutil.copy(img_path, destination_dir)

# Copy good images to train and test directories
copy_images(good_train, train_good_dir)
copy_images(good_test, test_good_dir)

# Copy all anomaly images to test directory
copy_images(anomaly_images, test_anomaly_dir)

print("Train-test split and organization completed successfully.")
# Out:
# Train-test split and organization completed successfully.

# %%
# Function to count images in a directory
def count_images(directory):
    return len([img for img in os.listdir(directory)
                if os.path.isfile(os.path.join(directory, img)) and img.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))])

# Count images
train_good_count = count_images(train_good_dir)
test_good_count = count_images(test_good_dir)
test_anomaly_count = count_images(test_anomaly_dir)

# Print the counts
print(f"Number of good images in training directory: {train_good_count}")
print(f"Number of good images in testing directory: {test_good_count}")
print(f"Number of anomaly images in testing directory: {test_anomaly_count}")
# Out:
# Number of good images in training directory: 800
# Number of good images in testing directory: 200
# Number of anomaly images in testing directory: 150

# %% [markdown]
# ## Class 3

# %%
# Define paths for class 1 
good_images_dir = 'raw/Class3'
anomaly_images_dir = 'raw/Class3_def'
train_dir = 'differnet-master/DAGM_dataset/DAGM_class_3/train'
train_good_dir = os.path.join(train_dir, 'good')
test_dir = 'differnet-master/DAGM_dataset/DAGM_class_3/test'
test_anomaly_dir = os.path.join(test_dir, 'anomaly')
test_good_dir = os.path.join(test_dir, 'good')

# Create train and test directories if they don't exist
os.makedirs(train_good_dir, exist_ok=True)
os.makedirs(test_anomaly_dir, exist_ok=True)
os.makedirs(test_good_dir, exist_ok=True)


# List all images
def list_images(directory):
    return [os.path.join(directory, img) for img in os.listdir(directory)
            if os.path.isfile(os.path.join(directory, img)) and img.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]

good_images = list_images(good_images_dir)
anomaly_images = list_images(anomaly_images_dir)

# Ensure that there are images to split
if not good_images:
    raise ValueError(f"No images found in the good images directory: {good_images_dir}")
if not anomaly_images:
    raise ValueError(f"No images found in the anomaly images directory: {anomaly_images_dir}")


# Split only good images into training and test sets
good_train, good_test = train_test_split(good_images, test_size=0.2, random_state=42)

# Function to copy images to their respective directories
def copy_images(image_list, destination_dir):
    for img_path in image_list:
        shutil.copy(img_path, destination_dir)

# Copy good images to train and test directories
copy_images(good_train, train_good_dir)
copy_images(good_test, test_good_dir)

# Copy all anomaly images to test directory
copy_images(anomaly_images, test_anomaly_dir)

print("Train-test split and organization completed successfully.")


# Function to count images in a directory
def count_images(directory):
    return len([img for img in os.listdir(directory)
                if os.path.isfile(os.path.join(directory, img)) and img.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))])

# Count images
train_good_count = count_images(train_good_dir)
test_good_count = count_images(test_good_dir)
test_anomaly_count = count_images(test_anomaly_dir)

# Print the counts
print(f"Number of good images in training directory: {train_good_count}")
print(f"Number of good images in testing directory: {test_good_count}")
print(f"Number of anomaly images in testing directory: {test_anomaly_count}")
# Out:
# Train-test split and organization completed successfully.
# Number of good images in training directory: 800
# Number of good images in testing directory: 200
# Number of anomaly images in testing directory: 150

# %% [markdown]
# ## Class 4

# %%
# Define paths for class 1 
good_images_dir = 'raw/Class4'
anomaly_images_dir = 'raw/Class4_def'
train_dir = 'differnet-master/DAGM_dataset/DAGM_class_4/train'
train_good_dir = os.path.join(train_dir, 'good')
test_dir = 'differnet-master/DAGM_dataset/DAGM_class_4/test'
test_anomaly_dir = os.path.join(test_dir, 'anomaly')
test_good_dir = os.path.join(test_dir, 'good')

# Create train and test directories if they don't exist
os.makedirs(train_good_dir, exist_ok=True)
os.makedirs(test_anomaly_dir, exist_ok=True)
os.makedirs(test_good_dir, exist_ok=True)


# List all images
def list_images(directory):
    return [os.path.join(directory, img) for img in os.listdir(directory)
            if os.path.isfile(os.path.join(directory, img)) and img.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]

good_images = list_images(good_images_dir)
anomaly_images = list_images(anomaly_images_dir)

# Ensure that there are images to split
if not good_images:
    raise ValueError(f"No images found in the good images directory: {good_images_dir}")
if not anomaly_images:
    raise ValueError(f"No images found in the anomaly images directory: {anomaly_images_dir}")


# Split only good images into training and test sets
good_train, good_test = train_test_split(good_images, test_size=0.2, random_state=42)

# Function to copy images to their respective directories
def copy_images(image_list, destination_dir):
    for img_path in image_list:
        shutil.copy(img_path, destination_dir)

# Copy good images to train and test directories
copy_images(good_train, train_good_dir)
copy_images(good_test, test_good_dir)

# Copy all anomaly images to test directory
copy_images(anomaly_images, test_anomaly_dir)

print("Train-test split and organization completed successfully.")


# Function to count images in a directory
def count_images(directory):
    return len([img for img in os.listdir(directory)
                if os.path.isfile(os.path.join(directory, img)) and img.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))])

# Count images
train_good_count = count_images(train_good_dir)
test_good_count = count_images(test_good_dir)
test_anomaly_count = count_images(test_anomaly_dir)

# Print the counts
print(f"Number of good images in training directory: {train_good_count}")
print(f"Number of good images in testing directory: {test_good_count}")
print(f"Number of anomaly images in testing directory: {test_anomaly_count}")
# Out:
# Train-test split and organization completed successfully.
# Number of good images in training directory: 800
# Number of good images in testing directory: 200
# Number of anomaly images in testing directory: 150

# %% [markdown]
# ## Class 5

# %%
# Define paths for class 1 
good_images_dir = 'raw/Class5'
anomaly_images_dir = 'raw/Class5_def'
train_dir = 'differnet-master/DAGM_dataset/DAGM_class_5/train'
train_good_dir = os.path.join(train_dir, 'good')
test_dir = 'differnet-master/DAGM_dataset/DAGM_class_5/test'
test_anomaly_dir = os.path.join(test_dir, 'anomaly')
test_good_dir = os.path.join(test_dir, 'good')

# Create train and test directories if they don't exist
os.makedirs(train_good_dir, exist_ok=True)
os.makedirs(test_anomaly_dir, exist_ok=True)
os.makedirs(test_good_dir, exist_ok=True)


# List all images
def list_images(directory):
    return [os.path.join(directory, img) for img in os.listdir(directory)
            if os.path.isfile(os.path.join(directory, img)) and img.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]

good_images = list_images(good_images_dir)
anomaly_images = list_images(anomaly_images_dir)

# Ensure that there are images to split
if not good_images:
    raise ValueError(f"No images found in the good images directory: {good_images_dir}")
if not anomaly_images:
    raise ValueError(f"No images found in the anomaly images directory: {anomaly_images_dir}")


# Split only good images into training and test sets
good_train, good_test = train_test_split(good_images, test_size=0.2, random_state=42)

# Function to copy images to their respective directories
def copy_images(image_list, destination_dir):
    for img_path in image_list:
        shutil.copy(img_path, destination_dir)

# Copy good images to train and test directories
copy_images(good_train, train_good_dir)
copy_images(good_test, test_good_dir)

# Copy all anomaly images to test directory
copy_images(anomaly_images, test_anomaly_dir)

print("Train-test split and organization completed successfully.")


# Function to count images in a directory
def count_images(directory):
    return len([img for img in os.listdir(directory)
                if os.path.isfile(os.path.join(directory, img)) and img.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))])

# Count images
train_good_count = count_images(train_good_dir)
test_good_count = count_images(test_good_dir)
test_anomaly_count = count_images(test_anomaly_dir)

# Print the counts
print(f"Number of good images in training directory: {train_good_count}")
print(f"Number of good images in testing directory: {test_good_count}")
print(f"Number of anomaly images in testing directory: {test_anomaly_count}")
# Out:
# Train-test split and organization completed successfully.
# Number of good images in training directory: 800
# Number of good images in testing directory: 200
# Number of anomaly images in testing directory: 150

# %% [markdown]
# ## Class 6

# %%
# Define paths for class 1 
good_images_dir = 'raw/Class6'
anomaly_images_dir = 'raw/Class6_def'
train_dir = 'differnet-master/DAGM_dataset/DAGM_class_6/train'
train_good_dir = os.path.join(train_dir, 'good')
test_dir = 'differnet-master/DAGM_dataset/DAGM_class_6/test'
test_anomaly_dir = os.path.join(test_dir, 'anomaly')
test_good_dir = os.path.join(test_dir, 'good')

# Create train and test directories if they don't exist
os.makedirs(train_good_dir, exist_ok=True)
os.makedirs(test_anomaly_dir, exist_ok=True)
os.makedirs(test_good_dir, exist_ok=True)


# List all images
def list_images(directory):
    return [os.path.join(directory, img) for img in os.listdir(directory)
            if os.path.isfile(os.path.join(directory, img)) and img.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]

good_images = list_images(good_images_dir)
anomaly_images = list_images(anomaly_images_dir)

# Ensure that there are images to split
if not good_images:
    raise ValueError(f"No images found in the good images directory: {good_images_dir}")
if not anomaly_images:
    raise ValueError(f"No images found in the anomaly images directory: {anomaly_images_dir}")


# Split only good images into training and test sets
good_train, good_test = train_test_split(good_images, test_size=0.2, random_state=42)

# Function to copy images to their respective directories
def copy_images(image_list, destination_dir):
    for img_path in image_list:
        shutil.copy(img_path, destination_dir)

# Copy good images to train and test directories
copy_images(good_train, train_good_dir)
copy_images(good_test, test_good_dir)

# Copy all anomaly images to test directory
copy_images(anomaly_images, test_anomaly_dir)

print("Train-test split and organization completed successfully.")


# Function to count images in a directory
def count_images(directory):
    return len([img for img in os.listdir(directory)
                if os.path.isfile(os.path.join(directory, img)) and img.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))])

# Count images
train_good_count = count_images(train_good_dir)
test_good_count = count_images(test_good_dir)
test_anomaly_count = count_images(test_anomaly_dir)

# Print the counts
print(f"Number of good images in training directory: {train_good_count}")
print(f"Number of good images in testing directory: {test_good_count}")
print(f"Number of anomaly images in testing directory: {test_anomaly_count}")
# Out:
# Train-test split and organization completed successfully.
# Number of good images in training directory: 800
# Number of good images in testing directory: 200
# Number of anomaly images in testing directory: 150

# %% [markdown]
# # Training All the Classes

# %% [markdown]
# ## Class 5 and 6

# %%
# !python main.py
# Out:
# Training model for DAGM_class_5
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# Train epoch 0
# 100%|█████████████████████████████████████████████| 9/9 [00:38<00:00,  4.24s/it]
# Epoch: 0.0 	 train loss: -0.0468
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 0.1 	 train loss: -1.0364
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 0.2 	 train loss: -1.5599
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 0.3 	 train loss: -1.9883
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 0.4 	 train loss: -2.2494
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 0.5 	 train loss: -2.3075
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 0.6 	 train loss: -2.5540
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 0.7 	 train loss: -2.7035
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:51<00:00,  2.86s/it]
# Epoch: 0 	 test_loss: -2.4382
# AUROC: 	 last: 0.7909 	 max: 0.7909 	 epoch_max: 0
#
# Train epoch 1
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 1.0 	 train loss: -2.9002
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 1.1 	 train loss: -2.9715
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 1.2 	 train loss: -2.6166
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 1.3 	 train loss: -3.0300
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 1.4 	 train loss: -3.1179
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 1.5 	 train loss: -2.9927
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 1.6 	 train loss: -3.0957
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 1.7 	 train loss: -2.9953
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:52<00:00,  2.89s/it]
# Epoch: 1 	 test_loss: -2.7482
# AUROC: 	 last: 0.8544 	 max: 0.8544 	 epoch_max: 1
#
# Train epoch 2
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 2.0 	 train loss: -3.2498
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 2.1 	 train loss: -3.3278
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 2.2 	 train loss: -3.3417
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 2.3 	 train loss: -3.3150
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 2.4 	 train loss: -3.3956
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 2.5 	 train loss: -3.4107
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 2.6 	 train loss: -3.5224
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 2.7 	 train loss: -3.5839
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:52<00:00,  2.87s/it]
# Epoch: 2 	 test_loss: 977.6352
# AUROC: 	 last: 0.9391 	 max: 0.9391 	 epoch_max: 2
#
# Train epoch 3
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 3.0 	 train loss: -3.3983
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.77s/it]
# Epoch: 3.1 	 train loss: -3.4318
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.78s/it]
# Epoch: 3.2 	 train loss: -3.6022
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.78s/it]
# Epoch: 3.3 	 train loss: -3.4965
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.78s/it]
# Epoch: 3.4 	 train loss: -3.6226
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.78s/it]
# Epoch: 3.5 	 train loss: -3.6949
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.78s/it]
# Epoch: 3.6 	 train loss: -3.6674
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.78s/it]
# Epoch: 3.7 	 train loss: -3.6648
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.84s/it]
# Epoch: 3 	 test_loss: -2.0944
# AUROC: 	 last: 0.9130 	 max: 0.9391 	 epoch_max: 2
#
# Train epoch 4
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 4.0 	 train loss: -3.7203
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.78s/it]
# Epoch: 4.1 	 train loss: -3.7370
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.78s/it]
# Epoch: 4.2 	 train loss: -3.6329
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.78s/it]
# Epoch: 4.3 	 train loss: -3.2294
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.77s/it]
# Epoch: 4.4 	 train loss: -3.6226
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 4.5 	 train loss: -3.6390
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 4.6 	 train loss: -3.6702
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 4.7 	 train loss: -3.6874
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.82s/it]
# Epoch: 4 	 test_loss: -1.3787
# AUROC: 	 last: 0.9249 	 max: 0.9391 	 epoch_max: 2
#
# Train epoch 5
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 5.0 	 train loss: -3.7968
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 5.1 	 train loss: -3.8003
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 5.2 	 train loss: -3.7649
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 5.3 	 train loss: -3.8016
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.74s/it]
# Epoch: 5.4 	 train loss: -3.8306
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 5.5 	 train loss: -3.8563
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 5.6 	 train loss: -3.8937
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 5.7 	 train loss: -3.8931
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:46<00:00,  2.73s/it]
# Epoch: 5 	 test_loss: 385.2723
# AUROC: 	 last: 0.9409 	 max: 0.9409 	 epoch_max: 5
#
# Train epoch 6
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.71s/it]
# Epoch: 6.0 	 train loss: -3.9055
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 6.1 	 train loss: -3.9088
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.71s/it]
# Epoch: 6.2 	 train loss: -3.8858
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.71s/it]
# Epoch: 6.3 	 train loss: -3.9277
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 6.4 	 train loss: -3.9552
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 6.5 	 train loss: -3.9653
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 6.6 	 train loss: -3.7048
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.71s/it]
# Epoch: 6.7 	 train loss: -3.8782
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:46<00:00,  2.74s/it]
# Epoch: 6 	 test_loss: -3.1413
# AUROC: 	 last: 0.9246 	 max: 0.9409 	 epoch_max: 5
#
# Train epoch 7
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 7.0 	 train loss: -3.8508
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 7.1 	 train loss: -3.9026
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.75s/it]
# Epoch: 7.2 	 train loss: -3.9279
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.75s/it]
# Epoch: 7.3 	 train loss: -3.9507
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.76s/it]
# Epoch: 7.4 	 train loss: -3.9705
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.76s/it]
# Epoch: 7.5 	 train loss: -3.9852
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.78s/it]
# Epoch: 7.6 	 train loss: -3.9865
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.77s/it]
# Epoch: 7.7 	 train loss: -4.0076
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:47<00:00,  2.76s/it]
# Epoch: 7 	 test_loss: 840.8782
# AUROC: 	 last: 0.9653 	 max: 0.9653 	 epoch_max: 7
#
# Train epoch 8
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 8.0 	 train loss: -4.0259
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 8.1 	 train loss: -3.9777
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.78s/it]
# Epoch: 8.2 	 train loss: -3.5917
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.77s/it]
# Epoch: 8.3 	 train loss: -3.4898
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 8.4 	 train loss: -3.8611
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.78s/it]
# Epoch: 8.5 	 train loss: -3.8979
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.77s/it]
# Epoch: 8.6 	 train loss: -3.9973
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.78s/it]
# Epoch: 8.7 	 train loss: -4.0031
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:47<00:00,  2.75s/it]
# Epoch: 8 	 test_loss: 1023.6486
# AUROC: 	 last: 0.9556 	 max: 0.9653 	 epoch_max: 7
#
# Train epoch 9
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 9.0 	 train loss: -4.0481
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 9.1 	 train loss: -4.0413
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 9.2 	 train loss: -4.0445
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 9.3 	 train loss: -4.0716
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.74s/it]
# Epoch: 9.4 	 train loss: -4.0620
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.71s/it]
# Epoch: 9.5 	 train loss: -4.0725
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.76s/it]
# Epoch: 9.6 	 train loss: -4.0572
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.71s/it]
# Epoch: 9.7 	 train loss: -4.0850
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:47<00:00,  2.75s/it]
# Epoch: 9 	 test_loss: 390.6833
# AUROC: 	 last: 0.9615 	 max: 0.9653 	 epoch_max: 7
#
# Train epoch 10
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.71s/it]
# Epoch: 10.0 	 train loss: -4.0800
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 10.1 	 train loss: -4.0651
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 10.2 	 train loss: -4.0888
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 10.3 	 train loss: -4.1035
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 10.4 	 train loss: -4.1214
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 10.5 	 train loss: -4.0844
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 10.6 	 train loss: -4.1105
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 10.7 	 train loss: -4.1316
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:47<00:00,  2.76s/it]
# Epoch: 10 	 test_loss: 1472.0543
# AUROC: 	 last: 0.9714 	 max: 0.9714 	 epoch_max: 10
#
# Train epoch 11
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 11.0 	 train loss: -4.1511
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.70s/it]
# Epoch: 11.1 	 train loss: -4.1486
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.71s/it]
# Epoch: 11.2 	 train loss: -4.1115
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 11.3 	 train loss: -4.1632
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.74s/it]
# Epoch: 11.4 	 train loss: -4.1456
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 11.5 	 train loss: -4.1562
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.71s/it]
# Epoch: 11.6 	 train loss: -4.1498
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 11.7 	 train loss: -4.1700
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:46<00:00,  2.74s/it]
# Epoch: 11 	 test_loss: 3952.4292
# AUROC: 	 last: 0.9575 	 max: 0.9714 	 epoch_max: 10
#
# Train epoch 12
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 12.0 	 train loss: -4.1568
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.76s/it]
# Epoch: 12.1 	 train loss: -4.1607
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.77s/it]
# Epoch: 12.2 	 train loss: -4.1892
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.75s/it]
# Epoch: 12.3 	 train loss: -4.1814
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.77s/it]
# Epoch: 12.4 	 train loss: -4.1772
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 12.5 	 train loss: -4.1930
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 12.6 	 train loss: -4.1880
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 12.7 	 train loss: -4.1752
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.84s/it]
# Epoch: 12 	 test_loss: 5031.5962
# AUROC: 	 last: 0.9642 	 max: 0.9714 	 epoch_max: 10
#
# Train epoch 13
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 13.0 	 train loss: -4.2189
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 13.1 	 train loss: -4.2064
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 13.2 	 train loss: -4.2308
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.78s/it]
# Epoch: 13.3 	 train loss: -4.2340
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 13.4 	 train loss: -4.2223
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 13.5 	 train loss: -4.2186
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 13.6 	 train loss: -4.2611
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.88s/it]
# Epoch: 13.7 	 train loss: -4.2191
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:51<00:00,  2.87s/it]
# Epoch: 13 	 test_loss: 7046.6450
# AUROC: 	 last: 0.9618 	 max: 0.9714 	 epoch_max: 10
#
# Train epoch 14
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 14.0 	 train loss: -4.2323
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 14.1 	 train loss: -4.2559
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 14.2 	 train loss: -4.2372
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 14.3 	 train loss: -4.2569
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 14.4 	 train loss: -4.2637
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 14.5 	 train loss: -4.2531
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 14.6 	 train loss: -4.2572
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 14.7 	 train loss: -4.2581
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.84s/it]
# Epoch: 14 	 test_loss: 12283.2549
# AUROC: 	 last: 0.9705 	 max: 0.9714 	 epoch_max: 10
#
# Train epoch 15
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 15.0 	 train loss: -4.2278
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 15.1 	 train loss: -4.2621
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.78s/it]
# Epoch: 15.2 	 train loss: -4.2671
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.78s/it]
# Epoch: 15.3 	 train loss: -4.2607
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 15.4 	 train loss: -4.2663
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 15.5 	 train loss: -4.3008
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.78s/it]
# Epoch: 15.6 	 train loss: -4.2009
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.78s/it]
# Epoch: 15.7 	 train loss: -4.2650
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:51<00:00,  2.85s/it]
# Epoch: 15 	 test_loss: 5383.9438
# AUROC: 	 last: 0.9639 	 max: 0.9714 	 epoch_max: 10
#
# Train epoch 16
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 16.0 	 train loss: -4.2697
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 16.1 	 train loss: -4.2780
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 16.2 	 train loss: -4.3061
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 16.3 	 train loss: -4.2909
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 16.4 	 train loss: -4.3011
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 16.5 	 train loss: -4.3038
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 16.6 	 train loss: -4.3158
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 16.7 	 train loss: -4.2957
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.84s/it]
# Epoch: 16 	 test_loss: 34015.7227
# AUROC: 	 last: 0.9725 	 max: 0.9725 	 epoch_max: 16
#
# Train epoch 17
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 17.0 	 train loss: -4.3107
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 17.1 	 train loss: -4.3270
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 17.2 	 train loss: -4.3145
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 17.3 	 train loss: -4.3200
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 17.4 	 train loss: -4.3277
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 17.5 	 train loss: -4.3040
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 17.6 	 train loss: -4.3394
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 17.7 	 train loss: -4.3573
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.83s/it]
# Epoch: 17 	 test_loss: 1973.2748
# AUROC: 	 last: 0.9702 	 max: 0.9725 	 epoch_max: 16
#
# Train epoch 18
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 18.0 	 train loss: -4.3593
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 18.1 	 train loss: -4.3293
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 18.2 	 train loss: -4.3582
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 18.3 	 train loss: -4.3222
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 18.4 	 train loss: -4.3461
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 18.5 	 train loss: -4.3584
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 18.6 	 train loss: -4.3762
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 18.7 	 train loss: -4.3660
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.82s/it]
# Epoch: 18 	 test_loss: 10331.0645
# AUROC: 	 last: 0.9653 	 max: 0.9725 	 epoch_max: 16
#
# Train epoch 19
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 19.0 	 train loss: -4.3492
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 19.1 	 train loss: -4.3486
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.78s/it]
# Epoch: 19.2 	 train loss: -4.3226
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.78s/it]
# Epoch: 19.3 	 train loss: -4.2954
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 19.4 	 train loss: -4.3286
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 19.5 	 train loss: -4.3502
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 19.6 	 train loss: -4.3585
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 19.7 	 train loss: -4.3656
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.82s/it]
# Epoch: 19 	 test_loss: 562.1971
# AUROC: 	 last: 0.9673 	 max: 0.9725 	 epoch_max: 16
#
# Train epoch 20
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 20.0 	 train loss: -4.3821
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 20.1 	 train loss: -4.3939
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 20.2 	 train loss: -4.4019
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 20.3 	 train loss: -4.3723
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 20.4 	 train loss: -4.3777
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 20.5 	 train loss: -4.3664
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 20.6 	 train loss: -4.3916
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 20.7 	 train loss: -4.3947
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.82s/it]
# Epoch: 20 	 test_loss: 3414.5208
# AUROC: 	 last: 0.9662 	 max: 0.9725 	 epoch_max: 16
#
# Train epoch 21
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 21.0 	 train loss: -4.3996
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 21.1 	 train loss: -4.3882
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 21.2 	 train loss: -4.4146
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 21.3 	 train loss: -4.4108
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 21.4 	 train loss: -4.3877
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 21.5 	 train loss: -4.4001
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 21.6 	 train loss: -4.4205
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 21.7 	 train loss: -4.4302
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:51<00:00,  2.86s/it]
# Epoch: 21 	 test_loss: 9475.9453
# AUROC: 	 last: 0.9647 	 max: 0.9725 	 epoch_max: 16
#
# Train epoch 22
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 22.0 	 train loss: -4.4252
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 22.1 	 train loss: -4.4123
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 22.2 	 train loss: -4.3783
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 22.3 	 train loss: -4.3914
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 22.4 	 train loss: -4.4229
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.88s/it]
# Epoch: 22.5 	 train loss: 8.9247
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 22.6 	 train loss: -3.0571
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 22.7 	 train loss: -3.5078
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:52<00:00,  2.88s/it]
# Epoch: 22 	 test_loss: 25.0728
# AUROC: 	 last: 0.8298 	 max: 0.9725 	 epoch_max: 16
#
# Train epoch 23
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 23.0 	 train loss: -3.7723
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 23.1 	 train loss: -4.0993
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 23.2 	 train loss: -4.1835
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 23.3 	 train loss: -4.1369
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 23.4 	 train loss: -4.2670
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 23.5 	 train loss: -4.2765
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 23.6 	 train loss: -4.2964
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 23.7 	 train loss: -4.3413
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:52<00:00,  2.88s/it]
# Epoch: 23 	 test_loss: 1380.0382
# AUROC: 	 last: 0.9669 	 max: 0.9725 	 epoch_max: 16
# Training time for DAGM_class_5: 7483.31 seconds
#
# Training model for DAGM_class_6
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# Train epoch 0
# 100%|█████████████████████████████████████████████| 9/9 [00:27<00:00,  3.02s/it]
# Epoch: 0.0 	 train loss: -0.0422
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.98s/it]
# Epoch: 0.1 	 train loss: -1.0435
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.98s/it]
# Epoch: 0.2 	 train loss: -1.7660
# 100%|█████████████████████████████████████████████| 9/9 [00:27<00:00,  3.00s/it]
# Epoch: 0.3 	 train loss: -2.0402
# 100%|█████████████████████████████████████████████| 9/9 [00:27<00:00,  3.00s/it]
# Epoch: 0.4 	 train loss: -2.3282
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# Epoch: 0.5 	 train loss: -2.3630
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.99s/it]
# Epoch: 0.6 	 train loss: -2.5488
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# Epoch: 0.7 	 train loss: -2.7574
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:53<00:00,  2.91s/it]
# Epoch: 0 	 test_loss: 0.6768
# AUROC: 	 last: 0.8936 	 max: 0.8936 	 epoch_max: 0
#
# Train epoch 1
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# Epoch: 1.0 	 train loss: -2.8273
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.96s/it]
# Epoch: 1.1 	 train loss: -2.8144
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.96s/it]
# Epoch: 1.2 	 train loss: -2.9109
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 1.3 	 train loss: -2.9548
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 1.4 	 train loss: -3.0499
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 1.5 	 train loss: -3.0400
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 1.6 	 train loss: -3.0758
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 1.7 	 train loss: -3.1231
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.80s/it]
# Epoch: 1 	 test_loss: 120.1675
# AUROC: 	 last: 0.9656 	 max: 0.9656 	 epoch_max: 1
#
# Train epoch 2
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.99s/it]
# Epoch: 2.0 	 train loss: -3.0991
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# Epoch: 2.1 	 train loss: -2.9269
# 100%|█████████████████████████████████████████████| 9/9 [00:27<00:00,  3.02s/it]
# Epoch: 2.2 	 train loss: -3.0381
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.99s/it]
# Epoch: 2.3 	 train loss: -3.0740
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.99s/it]
# Epoch: 2.4 	 train loss: -3.1441
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# Epoch: 2.5 	 train loss: -3.1997
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# Epoch: 2.6 	 train loss: -3.2494
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.98s/it]
# Epoch: 2.7 	 train loss: -3.2259
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:51<00:00,  2.86s/it]
# Epoch: 2 	 test_loss: -3.2145
# AUROC: 	 last: 0.9752 	 max: 0.9752 	 epoch_max: 2
#
# Train epoch 3
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# Epoch: 3.0 	 train loss: -3.2687
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.98s/it]
# Epoch: 3.1 	 train loss: -3.2938
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.98s/it]
# Epoch: 3.2 	 train loss: -3.3213
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# Epoch: 3.3 	 train loss: -3.2387
# 100%|█████████████████████████████████████████████| 9/9 [00:27<00:00,  3.01s/it]
# Epoch: 3.4 	 train loss: -3.3354
# 100%|█████████████████████████████████████████████| 9/9 [00:27<00:00,  3.01s/it]
# Epoch: 3.5 	 train loss: -3.3432
# 100%|█████████████████████████████████████████████| 9/9 [00:27<00:00,  3.00s/it]
# Epoch: 3.6 	 train loss: -3.3723
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.99s/it]
# Epoch: 3.7 	 train loss: -3.3401
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:51<00:00,  2.86s/it]
# Epoch: 3 	 test_loss: -3.2941
# AUROC: 	 last: 0.9687 	 max: 0.9752 	 epoch_max: 2
#
# Train epoch 4
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# Epoch: 4.0 	 train loss: -3.3832
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.96s/it]
# Epoch: 4.1 	 train loss: -3.4289
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.94s/it]
# Epoch: 4.2 	 train loss: -3.3565
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 4.3 	 train loss: -3.3916
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 4.4 	 train loss: -3.4028
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 4.5 	 train loss: -3.4254
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 4.6 	 train loss: -3.1778
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 4.7 	 train loss: -3.4060
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:51<00:00,  2.86s/it]
# Epoch: 4 	 test_loss: -3.3631
# AUROC: 	 last: 0.9650 	 max: 0.9752 	 epoch_max: 2
#
# Train epoch 5
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.98s/it]
# Epoch: 5.0 	 train loss: -3.4579
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.98s/it]
# Epoch: 5.1 	 train loss: -3.4325
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# Epoch: 5.2 	 train loss: -3.4270
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.96s/it]
# Epoch: 5.3 	 train loss: -3.3969
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.98s/it]
# Epoch: 5.4 	 train loss: -3.4615
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.96s/it]
# Epoch: 5.5 	 train loss: -3.4890
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.96s/it]
# Epoch: 5.6 	 train loss: -3.4978
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.98s/it]
# Epoch: 5.7 	 train loss: -3.5155
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:51<00:00,  2.87s/it]
# Epoch: 5 	 test_loss: -3.1185
# AUROC: 	 last: 0.9625 	 max: 0.9752 	 epoch_max: 2
#
# Train epoch 6
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.99s/it]
# Epoch: 6.0 	 train loss: -3.5177
# 100%|█████████████████████████████████████████████| 9/9 [00:27<00:00,  3.02s/it]
# Epoch: 6.1 	 train loss: -3.5315
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# Epoch: 6.2 	 train loss: -3.5386
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  3.00s/it]
# Epoch: 6.3 	 train loss: -3.5318
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# Epoch: 6.4 	 train loss: -3.5196
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# Epoch: 6.5 	 train loss: -3.5442
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.99s/it]
# Epoch: 6.6 	 train loss: -3.5508
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.98s/it]
# Epoch: 6.7 	 train loss: 6.8075
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:51<00:00,  2.87s/it]
# Epoch: 6 	 test_loss: -2.7010
# AUROC: 	 last: 0.8404 	 max: 0.9752 	 epoch_max: 2
#
# Train epoch 7
# 100%|█████████████████████████████████████████████| 9/9 [00:27<00:00,  3.00s/it]
# Epoch: 7.0 	 train loss: -2.5622
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.99s/it]
# Epoch: 7.1 	 train loss: -3.0824
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.99s/it]
# Epoch: 7.2 	 train loss: -3.4111
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.98s/it]
# Epoch: 7.3 	 train loss: -3.4256
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.96s/it]
# Epoch: 7.4 	 train loss: -3.4944
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.99s/it]
# Epoch: 7.5 	 train loss: -3.4962
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# Epoch: 7.6 	 train loss: -3.4985
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.96s/it]
# Epoch: 7.7 	 train loss: -3.5423
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:52<00:00,  2.88s/it]
# Epoch: 7 	 test_loss: -3.4855
# AUROC: 	 last: 0.9410 	 max: 0.9752 	 epoch_max: 2
#
# Train epoch 8
# 100%|█████████████████████████████████████████████| 9/9 [00:27<00:00,  3.01s/it]
# Epoch: 8.0 	 train loss: -3.5352
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.99s/it]
# Epoch: 8.1 	 train loss: -3.5466
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.98s/it]
# Epoch: 8.2 	 train loss: -3.5668
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 8.3 	 train loss: -3.5709
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.99s/it]
# Epoch: 8.4 	 train loss: -3.5559
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 8.5 	 train loss: -3.5630
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 8.6 	 train loss: -3.6044
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 8.7 	 train loss: -3.5764
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.83s/it]
# Epoch: 8 	 test_loss: -3.4666
# AUROC: 	 last: 0.9438 	 max: 0.9752 	 epoch_max: 2
#
# Train epoch 9
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 9.0 	 train loss: -3.5763
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 9.1 	 train loss: -3.5212
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 9.2 	 train loss: -3.6092
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 9.3 	 train loss: -3.6226
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 9.4 	 train loss: -3.6282
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 9.5 	 train loss: -3.6266
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 9.6 	 train loss: -3.6345
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 9.7 	 train loss: -3.6332
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.83s/it]
# Epoch: 9 	 test_loss: -2.9169
# AUROC: 	 last: 0.9694 	 max: 0.9752 	 epoch_max: 2
#
# Train epoch 10
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 10.0 	 train loss: -3.6564
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.89s/it]
# Epoch: 10.1 	 train loss: -3.6471
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 10.2 	 train loss: -3.6861
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 10.3 	 train loss: -3.6601
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 10.4 	 train loss: -3.6964
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 10.5 	 train loss: -3.6937
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 10.6 	 train loss: -3.6890
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 10.7 	 train loss: -3.6939
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.82s/it]
# Epoch: 10 	 test_loss: 19.9896
# AUROC: 	 last: 0.9751 	 max: 0.9752 	 epoch_max: 2
#
# Train epoch 11
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 11.0 	 train loss: -3.7111
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 11.1 	 train loss: -3.7283
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 11.2 	 train loss: -3.7181
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 11.3 	 train loss: -3.6808
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 11.4 	 train loss: -3.6982
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 11.5 	 train loss: -3.6537
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 11.6 	 train loss: -3.6972
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 11.7 	 train loss: -3.6068
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.81s/it]
# Epoch: 11 	 test_loss: 472.2904
# AUROC: 	 last: 0.9561 	 max: 0.9752 	 epoch_max: 2
#
# Train epoch 12
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 12.0 	 train loss: -3.7002
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 12.1 	 train loss: -3.6951
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 12.2 	 train loss: -3.6719
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 12.3 	 train loss: -3.6831
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.94s/it]
# Epoch: 12.4 	 train loss: -3.5444
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 12.5 	 train loss: -3.6745
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 12.6 	 train loss: -3.7189
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 12.7 	 train loss: -3.7315
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.82s/it]
# Epoch: 12 	 test_loss: -3.6731
# AUROC: 	 last: 0.9654 	 max: 0.9752 	 epoch_max: 2
#
# Train epoch 13
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 13.0 	 train loss: -3.7453
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 13.1 	 train loss: -3.7417
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 13.2 	 train loss: -3.7638
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 13.3 	 train loss: -3.7367
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 13.4 	 train loss: -3.7718
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 13.5 	 train loss: -3.7100
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 13.6 	 train loss: -3.7654
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 13.7 	 train loss: -3.7720
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.82s/it]
# Epoch: 13 	 test_loss: -3.5330
# AUROC: 	 last: 0.9654 	 max: 0.9752 	 epoch_max: 2
#
# Train epoch 14
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 14.0 	 train loss: -3.7833
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 14.1 	 train loss: -3.7839
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 14.2 	 train loss: -3.7877
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 14.3 	 train loss: -3.8001
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 14.4 	 train loss: -3.7923
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 14.5 	 train loss: -3.8054
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 14.6 	 train loss: -3.8029
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 14.7 	 train loss: -3.7846
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.82s/it]
# Epoch: 14 	 test_loss: -0.3740
# AUROC: 	 last: 0.9668 	 max: 0.9752 	 epoch_max: 2
#
# Train epoch 15
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 15.0 	 train loss: -3.7826
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 15.1 	 train loss: -3.8113
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 15.2 	 train loss: -3.8015
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 15.3 	 train loss: -3.7938
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 15.4 	 train loss: -3.8047
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 15.5 	 train loss: -3.8213
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 15.6 	 train loss: -3.8222
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 15.7 	 train loss: -3.8298
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.81s/it]
# Epoch: 15 	 test_loss: -3.4357
# AUROC: 	 last: 0.9736 	 max: 0.9752 	 epoch_max: 2
#
# Train epoch 16
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 16.0 	 train loss: -3.8309
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 16.1 	 train loss: -3.8394
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 16.2 	 train loss: -3.8305
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 16.3 	 train loss: -3.8546
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 16.4 	 train loss: -3.8329
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 16.5 	 train loss: -3.8520
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 16.6 	 train loss: -3.8557
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 16.7 	 train loss: -3.8273
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.81s/it]
# Epoch: 16 	 test_loss: -3.7738
# AUROC: 	 last: 0.9787 	 max: 0.9787 	 epoch_max: 16
#
# Train epoch 17
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 17.0 	 train loss: -3.8439
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 17.1 	 train loss: -3.8743
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 17.2 	 train loss: -3.8642
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 17.3 	 train loss: -3.8716
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 17.4 	 train loss: -3.8766
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 17.5 	 train loss: -3.8685
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 17.6 	 train loss: -3.8658
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 17.7 	 train loss: -3.8703
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.81s/it]
# Epoch: 17 	 test_loss: 193.6513
# AUROC: 	 last: 0.9817 	 max: 0.9817 	 epoch_max: 17
#
# Train epoch 18
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 18.0 	 train loss: -3.8686
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 18.1 	 train loss: -3.8347
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 18.2 	 train loss: -3.8599
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 18.3 	 train loss: -3.8898
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 18.4 	 train loss: -3.8735
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 18.5 	 train loss: -3.8837
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 18.6 	 train loss: -3.5285
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 18.7 	 train loss: -3.1038
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.83s/it]
# Epoch: 18 	 test_loss: -3.2168
# AUROC: 	 last: 0.8225 	 max: 0.9817 	 epoch_max: 17
#
# Train epoch 19
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 19.0 	 train loss: -3.4719
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 19.1 	 train loss: -3.7001
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 19.2 	 train loss: -3.7690
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.96s/it]
# Epoch: 19.3 	 train loss: -3.8245
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 19.4 	 train loss: -3.8485
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 19.5 	 train loss: -3.8614
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 19.6 	 train loss: -3.8646
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 19.7 	 train loss: -3.8801
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.82s/it]
# Epoch: 19 	 test_loss: -3.7867
# AUROC: 	 last: 0.9710 	 max: 0.9817 	 epoch_max: 17
#
# Train epoch 20
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 20.0 	 train loss: -3.8870
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 20.1 	 train loss: -3.9076
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 20.2 	 train loss: -3.8871
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 20.3 	 train loss: -3.8964
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 20.4 	 train loss: -3.8968
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 20.5 	 train loss: -3.9204
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 20.6 	 train loss: -3.8975
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 20.7 	 train loss: -3.9060
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.81s/it]
# Epoch: 20 	 test_loss: 98.2824
# AUROC: 	 last: 0.9719 	 max: 0.9817 	 epoch_max: 17
#
# Train epoch 21
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 21.0 	 train loss: -3.8836
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 21.1 	 train loss: -3.8920
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 21.2 	 train loss: -3.9028
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 21.3 	 train loss: -3.9146
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 21.4 	 train loss: -3.9322
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 21.5 	 train loss: -3.9181
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 21.6 	 train loss: -3.9466
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 21.7 	 train loss: -3.9385
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.82s/it]
# Epoch: 21 	 test_loss: 244.5433
# AUROC: 	 last: 0.9524 	 max: 0.9817 	 epoch_max: 17
#
# Train epoch 22
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 22.0 	 train loss: -3.9601
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 22.1 	 train loss: -3.9550
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 22.2 	 train loss: -3.9527
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 22.3 	 train loss: -3.9675
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 22.4 	 train loss: -3.9446
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 22.5 	 train loss: -3.9269
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 22.6 	 train loss: -3.9527
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 22.7 	 train loss: -3.5789
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.81s/it]
# Epoch: 22 	 test_loss: -3.2015
# AUROC: 	 last: 0.9256 	 max: 0.9817 	 epoch_max: 17
#
# Train epoch 23
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.94s/it]
# Epoch: 23.0 	 train loss: -3.3725
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 23.1 	 train loss: -3.7832
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 23.2 	 train loss: -3.8662
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 23.3 	 train loss: -3.9135
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 23.4 	 train loss: -3.9138
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 23.5 	 train loss: -3.9409
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 23.6 	 train loss: -3.9528
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 23.7 	 train loss: -3.9486
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.82s/it]
# Epoch: 23 	 test_loss: -3.6427
# AUROC: 	 last: 0.9509 	 max: 0.9817 	 epoch_max: 17
# Training time for DAGM_class_6: 7727.44 seconds
#
# Training Summary:
# DAGM_class_5:
#   Model name: DAGM_model_DAGM_class_5
#   Training time: 7483.31 seconds
# DAGM_class_6:
#   Model name: DAGM_model_DAGM_class_6
#   Training time: 7727.44 seconds
#
# Total training time for all classes: 15210.76 seconds

# %% [markdown]
# ## Class 1 to 4

# %%
# !python main.py
# Out:
# Training model for DAGM_class_1
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# Train epoch 0
# 100%|█████████████████████████████████████████████| 9/9 [00:30<00:00,  3.43s/it]
# Epoch: 0.0 	 train loss: -0.0351
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 0.1 	 train loss: -0.9616
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.89s/it]
# Epoch: 0.2 	 train loss: -1.7658
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 0.3 	 train loss: -1.8414
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 0.4 	 train loss: -2.1230
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 0.5 	 train loss: -2.0801
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 0.6 	 train loss: -2.2008
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 0.7 	 train loss: -2.4657
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.81s/it]
# Epoch: 0 	 test_loss: -2.1785
# AUROC: 	 last: 0.5682 	 max: 0.5682 	 epoch_max: 0
#
# Train epoch 1
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.89s/it]
# Epoch: 1.0 	 train loss: -2.3683
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.89s/it]
# Epoch: 1.1 	 train loss: -2.6733
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 1.2 	 train loss: -2.5835
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.89s/it]
# Epoch: 1.3 	 train loss: -2.8052
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.89s/it]
# Epoch: 1.4 	 train loss: -2.8564
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 1.5 	 train loss: -2.9239
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 1.6 	 train loss: -2.9636
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 1.7 	 train loss: -3.0051
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:47<00:00,  2.76s/it]
# Epoch: 1 	 test_loss: -2.9916
# AUROC: 	 last: 0.6683 	 max: 0.6683 	 epoch_max: 1
#
# Train epoch 2
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 2.0 	 train loss: -3.0720
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.82s/it]
# Epoch: 2.1 	 train loss: -3.0761
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 2.2 	 train loss: -3.1131
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 2.3 	 train loss: -3.2051
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 2.4 	 train loss: -3.1199
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 2.5 	 train loss: -3.2367
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 2.6 	 train loss: -3.2807
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 2.7 	 train loss: 2207.9268
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:46<00:00,  2.74s/it]
# Epoch: 2 	 test_loss: -2.3303
# AUROC: 	 last: 0.3992 	 max: 0.6683 	 epoch_max: 1
#
# Train epoch 3
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 3.0 	 train loss: -2.5104
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.82s/it]
# Epoch: 3.1 	 train loss: -3.0759
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.82s/it]
# Epoch: 3.2 	 train loss: -3.2384
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.82s/it]
# Epoch: 3.3 	 train loss: -3.3330
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 3.4 	 train loss: -3.3885
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 3.5 	 train loss: -3.3802
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 3.6 	 train loss: -3.4639
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 3.7 	 train loss: -3.4422
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:48<00:00,  2.78s/it]
# Epoch: 3 	 test_loss: -3.3788
# AUROC: 	 last: 0.7348 	 max: 0.7348 	 epoch_max: 3
#
# Train epoch 4
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 4.0 	 train loss: -3.4256
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.89s/it]
# Epoch: 4.1 	 train loss: -3.4028
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 4.2 	 train loss: -3.3716
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 4.3 	 train loss: -3.3981
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 4.4 	 train loss: -3.4006
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 4.5 	 train loss: -3.4428
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 4.6 	 train loss: -3.3617
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.94s/it]
# Epoch: 4.7 	 train loss: -3.4264
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.82s/it]
# Epoch: 4 	 test_loss: -3.4112
# AUROC: 	 last: 0.7395 	 max: 0.7395 	 epoch_max: 4
#
# Train epoch 5
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 5.0 	 train loss: -3.3983
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 5.1 	 train loss: -3.4430
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.94s/it]
# Epoch: 5.2 	 train loss: -3.4971
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 5.3 	 train loss: -3.4348
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 5.4 	 train loss: -3.5440
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 5.5 	 train loss: -3.5629
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 5.6 	 train loss: -3.5768
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 5.7 	 train loss: -3.5447
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.81s/it]
# Epoch: 5 	 test_loss: -3.5321
# AUROC: 	 last: 0.7758 	 max: 0.7758 	 epoch_max: 5
#
# Train epoch 6
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 6.0 	 train loss: -3.5771
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 6.1 	 train loss: -3.5639
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.94s/it]
# Epoch: 6.2 	 train loss: -3.5892
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.94s/it]
# Epoch: 6.3 	 train loss: -3.6286
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 6.4 	 train loss: -3.5983
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 6.5 	 train loss: -3.6377
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 6.6 	 train loss: -3.6568
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 6.7 	 train loss: -3.6809
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.82s/it]
# Epoch: 6 	 test_loss: -3.6000
# AUROC: 	 last: 0.7958 	 max: 0.7958 	 epoch_max: 6
#
# Train epoch 7
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 7.0 	 train loss: -3.6667
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 7.1 	 train loss: -3.6694
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 7.2 	 train loss: -3.6305
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.91s/it]
# Epoch: 7.3 	 train loss: -3.6896
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 7.4 	 train loss: -3.7105
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 7.5 	 train loss: -3.7282
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 7.6 	 train loss: -3.7483
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 7.7 	 train loss: -3.7231
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:46<00:00,  2.74s/it]
# Epoch: 7 	 test_loss: -3.6625
# AUROC: 	 last: 0.7681 	 max: 0.7958 	 epoch_max: 6
#
# Train epoch 8
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 8.0 	 train loss: -3.7249
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 8.1 	 train loss: -3.7683
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 8.2 	 train loss: -3.7692
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 8.3 	 train loss: -3.7528
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 8.4 	 train loss: -3.7378
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 8.5 	 train loss: -3.7769
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 8.6 	 train loss: -3.8046
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 8.7 	 train loss: -3.7810
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:47<00:00,  2.75s/it]
# Epoch: 8 	 test_loss: -3.7054
# AUROC: 	 last: 0.7987 	 max: 0.7987 	 epoch_max: 8
#
# Train epoch 9
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 9.0 	 train loss: -3.7986
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 9.1 	 train loss: -3.8312
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 9.2 	 train loss: -3.7974
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 9.3 	 train loss: -3.7566
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 9.4 	 train loss: -3.7825
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 9.5 	 train loss: -3.8248
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 9.6 	 train loss: -3.7903
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 9.7 	 train loss: -3.8227
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:47<00:00,  2.75s/it]
# Epoch: 9 	 test_loss: -3.7692
# AUROC: 	 last: 0.8044 	 max: 0.8044 	 epoch_max: 9
#
# Train epoch 10
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 10.0 	 train loss: -3.8249
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 10.1 	 train loss: -3.8585
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.89s/it]
# Epoch: 10.2 	 train loss: -3.8612
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 10.3 	 train loss: -3.8727
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 10.4 	 train loss: -3.8679
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 10.5 	 train loss: -3.8617
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 10.6 	 train loss: -3.8641
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 10.7 	 train loss: -3.8723
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:47<00:00,  2.75s/it]
# Epoch: 10 	 test_loss: -3.7519
# AUROC: 	 last: 0.8260 	 max: 0.8260 	 epoch_max: 10
#
# Train epoch 11
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 11.0 	 train loss: -3.8438
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 11.1 	 train loss: -3.8566
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 11.2 	 train loss: -3.8908
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 11.3 	 train loss: -3.9166
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 11.4 	 train loss: -3.9328
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 11.5 	 train loss: -3.8793
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 11.6 	 train loss: -3.9038
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 11.7 	 train loss: -3.9249
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:47<00:00,  2.75s/it]
# Epoch: 11 	 test_loss: -3.8949
# AUROC: 	 last: 0.8219 	 max: 0.8260 	 epoch_max: 10
#
# Train epoch 12
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 12.0 	 train loss: -3.9523
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 12.1 	 train loss: -3.9364
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 12.2 	 train loss: -3.9465
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 12.3 	 train loss: -3.9640
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 12.4 	 train loss: -3.9476
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 12.5 	 train loss: -3.9373
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 12.6 	 train loss: -3.9641
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 12.7 	 train loss: -3.9574
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:47<00:00,  2.74s/it]
# Epoch: 12 	 test_loss: -3.0855
# AUROC: 	 last: 0.8201 	 max: 0.8260 	 epoch_max: 10
#
# Train epoch 13
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 13.0 	 train loss: -3.9358
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 13.1 	 train loss: -3.9530
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 13.2 	 train loss: -3.9426
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 13.3 	 train loss: -3.9326
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 13.4 	 train loss: -3.9591
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 13.5 	 train loss: -3.9861
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 13.6 	 train loss: -3.9879
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 13.7 	 train loss: -4.0090
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:47<00:00,  2.77s/it]
# Epoch: 13 	 test_loss: -3.9398
# AUROC: 	 last: 0.8314 	 max: 0.8314 	 epoch_max: 13
#
# Train epoch 14
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 14.0 	 train loss: -4.0186
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 14.1 	 train loss: -3.9945
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 14.2 	 train loss: -3.9682
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 14.3 	 train loss: -3.9842
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 14.4 	 train loss: -3.9733
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 14.5 	 train loss: -4.0198
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 14.6 	 train loss: -4.0203
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 14.7 	 train loss: -4.0394
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:47<00:00,  2.76s/it]
# Epoch: 14 	 test_loss: -2.7481
# AUROC: 	 last: 0.8539 	 max: 0.8539 	 epoch_max: 14
#
# Train epoch 15
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 15.0 	 train loss: -4.0457
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 15.1 	 train loss: -4.0145
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 15.2 	 train loss: -3.9358
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 15.3 	 train loss: -3.9974
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 15.4 	 train loss: -3.9975
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 15.5 	 train loss: -4.0182
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 15.6 	 train loss: -4.0170
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 15.7 	 train loss: -4.0236
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:47<00:00,  2.76s/it]
# Epoch: 15 	 test_loss: -3.9683
# AUROC: 	 last: 0.8446 	 max: 0.8539 	 epoch_max: 14
#
# Train epoch 16
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 16.0 	 train loss: -4.0350
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 16.1 	 train loss: -4.0550
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 16.2 	 train loss: -4.0607
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 16.3 	 train loss: -4.0676
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 16.4 	 train loss: -4.0915
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 16.5 	 train loss: -4.0704
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 16.6 	 train loss: -4.0561
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 16.7 	 train loss: -4.0661
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:47<00:00,  2.77s/it]
# Epoch: 16 	 test_loss: -3.8438
# AUROC: 	 last: 0.8456 	 max: 0.8539 	 epoch_max: 14
#
# Train epoch 17
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 17.0 	 train loss: -3.9994
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.88s/it]
# Epoch: 17.1 	 train loss: -4.0718
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 17.2 	 train loss: -4.0678
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 17.3 	 train loss: -4.0898
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 17.4 	 train loss: -4.0757
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 17.5 	 train loss: -4.0856
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 17.6 	 train loss: -4.1129
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 17.7 	 train loss: -4.1164
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.81s/it]
# Epoch: 17 	 test_loss: -4.0235
# AUROC: 	 last: 0.8572 	 max: 0.8572 	 epoch_max: 17
#
# Train epoch 18
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 18.0 	 train loss: -4.0859
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 18.1 	 train loss: -4.1088
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 18.2 	 train loss: -4.1043
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 18.3 	 train loss: -4.0505
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 18.4 	 train loss: -4.0755
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 18.5 	 train loss: -4.1272
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 18.6 	 train loss: -4.1226
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 18.7 	 train loss: -4.1346
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:47<00:00,  2.76s/it]
# Epoch: 18 	 test_loss: -4.0424
# AUROC: 	 last: 0.8786 	 max: 0.8786 	 epoch_max: 18
#
# Train epoch 19
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 19.0 	 train loss: -4.1337
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 19.1 	 train loss: -4.1300
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 19.2 	 train loss: -4.1391
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 19.3 	 train loss: -4.1237
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 19.4 	 train loss: -4.1364
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 19.5 	 train loss: -4.1496
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 19.6 	 train loss: -4.1624
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 19.7 	 train loss: -4.1579
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:47<00:00,  2.75s/it]
# Epoch: 19 	 test_loss: -3.9867
# AUROC: 	 last: 0.8520 	 max: 0.8786 	 epoch_max: 18
#
# Train epoch 20
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.89s/it]
# Epoch: 20.0 	 train loss: -4.1337
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 20.1 	 train loss: -4.1502
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 20.2 	 train loss: -4.1820
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 20.3 	 train loss: -4.1759
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 20.4 	 train loss: -4.1829
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 20.5 	 train loss: -3.3211
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.88s/it]
# Epoch: 20.6 	 train loss: -3.6424
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 20.7 	 train loss: -3.9556
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:47<00:00,  2.75s/it]
# Epoch: 20 	 test_loss: -3.9492
# AUROC: 	 last: 0.7916 	 max: 0.8786 	 epoch_max: 18
#
# Train epoch 21
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 21.0 	 train loss: -4.0834
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 21.1 	 train loss: -4.1188
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 21.2 	 train loss: -4.1242
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 21.3 	 train loss: -4.1475
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 21.4 	 train loss: -4.1667
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 21.5 	 train loss: -4.1564
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 21.6 	 train loss: -4.1853
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 21.7 	 train loss: -4.1585
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:47<00:00,  2.75s/it]
# Epoch: 21 	 test_loss: -4.1302
# AUROC: 	 last: 0.8547 	 max: 0.8786 	 epoch_max: 18
#
# Train epoch 22
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 22.0 	 train loss: -4.1771
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 22.1 	 train loss: -4.1760
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 22.2 	 train loss: -4.1610
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 22.3 	 train loss: -4.1353
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 22.4 	 train loss: -4.1905
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 22.5 	 train loss: -4.2167
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 22.6 	 train loss: -4.2165
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 22.7 	 train loss: -4.2202
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:47<00:00,  2.75s/it]
# Epoch: 22 	 test_loss: -4.1086
# AUROC: 	 last: 0.8810 	 max: 0.8810 	 epoch_max: 22
#
# Train epoch 23
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 23.0 	 train loss: -4.2413
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 23.1 	 train loss: -4.2185
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 23.2 	 train loss: -4.2082
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 23.3 	 train loss: -4.2043
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 23.4 	 train loss: -4.2310
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 23.5 	 train loss: -4.2470
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 23.6 	 train loss: -4.2390
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 23.7 	 train loss: -4.2436
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:48<00:00,  2.77s/it]
# Epoch: 23 	 test_loss: -4.1757
# AUROC: 	 last: 0.8731 	 max: 0.8810 	 epoch_max: 22
# Training time for DAGM_class_1: 7542.96 seconds
#
# Training model for DAGM_class_2
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# Train epoch 0
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# Epoch: 0.0 	 train loss: -0.0128
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 0.1 	 train loss: -0.9752
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 0.2 	 train loss: -1.6638
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 0.3 	 train loss: -1.9992
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 0.4 	 train loss: -2.1993
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 0.5 	 train loss: -2.0751
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 0.6 	 train loss: -2.2269
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 0.7 	 train loss: -2.4421
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.82s/it]
# Epoch: 0 	 test_loss: -2.0761
# AUROC: 	 last: 0.6201 	 max: 0.6201 	 epoch_max: 0
#
# Train epoch 1
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 1.0 	 train loss: -2.6232
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 1.1 	 train loss: -2.6943
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 1.2 	 train loss: -2.7357
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 1.3 	 train loss: -2.8550
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 1.4 	 train loss: -2.8111
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 1.5 	 train loss: -2.9276
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 1.6 	 train loss: -3.0033
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.82s/it]
# Epoch: 1.7 	 train loss: -3.0510
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.80s/it]
# Epoch: 1 	 test_loss: -3.0802
# AUROC: 	 last: 0.6690 	 max: 0.6690 	 epoch_max: 1
#
# Train epoch 2
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 2.0 	 train loss: -3.0344
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 2.1 	 train loss: -3.1299
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 2.2 	 train loss: -3.1565
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 2.3 	 train loss: -3.2063
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 2.4 	 train loss: -3.1970
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 2.5 	 train loss: -3.2418
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 2.6 	 train loss: -3.2372
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 2.7 	 train loss: -3.2400
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.80s/it]
# Epoch: 2 	 test_loss: -3.2928
# AUROC: 	 last: 0.6521 	 max: 0.6690 	 epoch_max: 1
#
# Train epoch 3
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 3.0 	 train loss: -3.3264
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 3.1 	 train loss: -3.2875
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 3.2 	 train loss: -3.3588
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.82s/it]
# Epoch: 3.3 	 train loss: -3.3600
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 3.4 	 train loss: -3.3956
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 3.5 	 train loss: -3.4702
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.82s/it]
# Epoch: 3.6 	 train loss: -3.4169
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.82s/it]
# Epoch: 3.7 	 train loss: -3.4340
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.81s/it]
# Epoch: 3 	 test_loss: -3.4405
# AUROC: 	 last: 0.6956 	 max: 0.6956 	 epoch_max: 3
#
# Train epoch 4
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 4.0 	 train loss: -3.4781
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 4.1 	 train loss: -3.4762
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.82s/it]
# Epoch: 4.2 	 train loss: -3.4755
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 4.3 	 train loss: -3.5421
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 4.4 	 train loss: -3.5520
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 4.5 	 train loss: -3.5816
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 4.6 	 train loss: -3.6087
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 4.7 	 train loss: -3.6052
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.81s/it]
# Epoch: 4 	 test_loss: -3.6069
# AUROC: 	 last: 0.7091 	 max: 0.7091 	 epoch_max: 4
#
# Train epoch 5
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 5.0 	 train loss: -3.6322
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 5.1 	 train loss: -3.6389
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 5.2 	 train loss: -3.6470
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 5.3 	 train loss: -3.6801
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 5.4 	 train loss: -3.6862
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 5.5 	 train loss: -3.6769
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 5.6 	 train loss: -3.6822
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 5.7 	 train loss: -3.6733
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:51<00:00,  2.86s/it]
# Epoch: 5 	 test_loss: -3.6335
# AUROC: 	 last: 0.7614 	 max: 0.7614 	 epoch_max: 5
#
# Train epoch 6
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 6.0 	 train loss: -3.6927
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 6.1 	 train loss: -3.7132
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 6.2 	 train loss: -3.7093
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 6.3 	 train loss: -3.7214
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 6.4 	 train loss: -3.7569
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 6.5 	 train loss: -3.7588
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 6.6 	 train loss: -3.7337
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 6.7 	 train loss: -3.7162
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.81s/it]
# Epoch: 6 	 test_loss: -3.7413
# AUROC: 	 last: 0.7460 	 max: 0.7614 	 epoch_max: 5
#
# Train epoch 7
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 7.0 	 train loss: -3.7780
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 7.1 	 train loss: -3.7833
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 7.2 	 train loss: -3.7795
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 7.3 	 train loss: -3.8236
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 7.4 	 train loss: -3.8264
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 7.5 	 train loss: -3.8078
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 7.6 	 train loss: -3.7956
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 7.7 	 train loss: -3.8118
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.82s/it]
# Epoch: 7 	 test_loss: -3.7721
# AUROC: 	 last: 0.7514 	 max: 0.7614 	 epoch_max: 5
#
# Train epoch 8
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 8.0 	 train loss: -3.8330
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 8.1 	 train loss: -3.8645
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.82s/it]
# Epoch: 8.2 	 train loss: -3.8790
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 8.3 	 train loss: -3.8795
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.82s/it]
# Epoch: 8.4 	 train loss: -3.8520
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 8.5 	 train loss: -3.8910
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 8.6 	 train loss: -3.8842
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 8.7 	 train loss: -3.8795
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.81s/it]
# Epoch: 8 	 test_loss: -3.8628
# AUROC: 	 last: 0.7227 	 max: 0.7614 	 epoch_max: 5
#
# Train epoch 9
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 9.0 	 train loss: -3.8684
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.79s/it]
# Epoch: 9.1 	 train loss: -3.9087
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.82s/it]
# Epoch: 9.2 	 train loss: -3.6616
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 9.3 	 train loss: -3.8373
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 9.4 	 train loss: -3.8611
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 9.5 	 train loss: -3.8943
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 9.6 	 train loss: -3.9244
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.80s/it]
# Epoch: 9.7 	 train loss: -3.9336
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:47<00:00,  2.75s/it]
# Epoch: 9 	 test_loss: -3.9419
# AUROC: 	 last: 0.7747 	 max: 0.7747 	 epoch_max: 9
#
# Train epoch 10
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 10.0 	 train loss: -3.9659
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 10.1 	 train loss: -3.9556
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 10.2 	 train loss: -3.9655
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 10.3 	 train loss: -3.9601
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 10.4 	 train loss: -3.9793
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 10.5 	 train loss: -3.9593
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.74s/it]
# Epoch: 10.6 	 train loss: -3.9697
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.74s/it]
# Epoch: 10.7 	 train loss: -3.9476
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:46<00:00,  2.74s/it]
# Epoch: 10 	 test_loss: -3.9724
# AUROC: 	 last: 0.7628 	 max: 0.7747 	 epoch_max: 9
#
# Train epoch 11
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 11.0 	 train loss: -3.9710
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 11.1 	 train loss: -3.9846
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.74s/it]
# Epoch: 11.2 	 train loss: -3.9868
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 11.3 	 train loss: -3.9757
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.74s/it]
# Epoch: 11.4 	 train loss: -4.0062
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.74s/it]
# Epoch: 11.5 	 train loss: -4.0327
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 11.6 	 train loss: -4.0320
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 11.7 	 train loss: -4.0473
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:46<00:00,  2.74s/it]
# Epoch: 11 	 test_loss: -4.0002
# AUROC: 	 last: 0.7609 	 max: 0.7747 	 epoch_max: 9
#
# Train epoch 12
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.74s/it]
# Epoch: 12.0 	 train loss: -4.0464
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 12.1 	 train loss: -4.0479
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 12.2 	 train loss: -4.0478
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 12.3 	 train loss: -4.0629
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.74s/it]
# Epoch: 12.4 	 train loss: -4.0657
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.74s/it]
# Epoch: 12.5 	 train loss: -4.0792
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.74s/it]
# Epoch: 12.6 	 train loss: -4.0534
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 12.7 	 train loss: -4.0614
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:46<00:00,  2.73s/it]
# Epoch: 12 	 test_loss: -4.0299
# AUROC: 	 last: 0.7622 	 max: 0.7747 	 epoch_max: 9
#
# Train epoch 13
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 13.0 	 train loss: -4.0717
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 13.1 	 train loss: -4.0769
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 13.2 	 train loss: -4.0819
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 13.3 	 train loss: -4.0812
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.74s/it]
# Epoch: 13.4 	 train loss: -4.0896
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 13.5 	 train loss: -4.1032
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 13.6 	 train loss: -4.0766
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 13.7 	 train loss: -4.1028
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:46<00:00,  2.73s/it]
# Epoch: 13 	 test_loss: -4.0465
# AUROC: 	 last: 0.7798 	 max: 0.7798 	 epoch_max: 13
#
# Train epoch 14
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 14.0 	 train loss: -4.0921
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 14.1 	 train loss: -4.0972
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 14.2 	 train loss: -4.1280
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 14.3 	 train loss: -4.1228
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 14.4 	 train loss: -4.1170
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.74s/it]
# Epoch: 14.5 	 train loss: -4.1194
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.74s/it]
# Epoch: 14.6 	 train loss: -4.1333
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.74s/it]
# Epoch: 14.7 	 train loss: -4.1427
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:46<00:00,  2.73s/it]
# Epoch: 14 	 test_loss: -4.0748
# AUROC: 	 last: 0.7780 	 max: 0.7798 	 epoch_max: 13
#
# Train epoch 15
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 15.0 	 train loss: -4.1400
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 15.1 	 train loss: -4.1118
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 15.2 	 train loss: -4.1612
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 15.3 	 train loss: -4.1568
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.72s/it]
# Epoch: 15.4 	 train loss: 96.2938
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 15.5 	 train loss: -3.1249
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.74s/it]
# Epoch: 15.6 	 train loss: -3.6659
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.74s/it]
# Epoch: 15.7 	 train loss: -3.9135
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:46<00:00,  2.73s/it]
# Epoch: 15 	 test_loss: -3.9581
# AUROC: 	 last: 0.7246 	 max: 0.7798 	 epoch_max: 13
#
# Train epoch 16
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.74s/it]
# Epoch: 16.0 	 train loss: -4.0247
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 16.1 	 train loss: -4.0542
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 16.2 	 train loss: -4.0696
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 16.3 	 train loss: -4.0604
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 16.4 	 train loss: -4.0616
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 16.5 	 train loss: -4.0882
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.75s/it]
# Epoch: 16.6 	 train loss: 714.7362
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Epoch: 16.7 	 train loss: -3.0066
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:46<00:00,  2.73s/it]
# Epoch: 16 	 test_loss: -3.1844
# AUROC: 	 last: 0.5505 	 max: 0.7798 	 epoch_max: 13
#
# Train epoch 17
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# ...
# Epoch: 10.3 	 train loss: -3.7034
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 10.4 	 train loss: -3.6603
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 10.5 	 train loss: -3.6769
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 10.6 	 train loss: -3.6550
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 10.7 	 train loss: -3.6976
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.83s/it]
# Epoch: 10 	 test_loss: 21.4048
# AUROC: 	 last: 0.9787 	 max: 0.9787 	 epoch_max: 10
#
# Train epoch 11
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 11.0 	 train loss: -3.6855
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 11.1 	 train loss: -3.7263
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 11.2 	 train loss: -3.7233
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 11.3 	 train loss: -3.7300
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 11.4 	 train loss: -3.7303
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.89s/it]
# Epoch: 11.5 	 train loss: -3.7131
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 11.6 	 train loss: -3.7476
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 11.7 	 train loss: -3.7388
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:51<00:00,  2.86s/it]
# Epoch: 11 	 test_loss: 16.5747
# AUROC: 	 last: 0.9840 	 max: 0.9840 	 epoch_max: 11
#
# Train epoch 12
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 12.0 	 train loss: -3.7421
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 12.1 	 train loss: -3.7307
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 12.2 	 train loss: -3.7384
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 12.3 	 train loss: -3.7477
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 12.4 	 train loss: -3.7337
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 12.5 	 train loss: -3.7444
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 12.6 	 train loss: -3.7650
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 12.7 	 train loss: -3.7965
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.83s/it]
# Epoch: 12 	 test_loss: -2.4700
# AUROC: 	 last: 0.9819 	 max: 0.9840 	 epoch_max: 11
#
# Train epoch 13
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 13.0 	 train loss: -3.7869
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 13.1 	 train loss: -3.7826
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.82s/it]
# Epoch: 13.2 	 train loss: -3.7749
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 13.3 	 train loss: -3.7634
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 13.4 	 train loss: -3.7963
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 13.5 	 train loss: -3.8029
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 13.6 	 train loss: -3.7085
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.82s/it]
# Epoch: 13.7 	 train loss: -3.7522
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.84s/it]
# Epoch: 13 	 test_loss: 53.4412
# AUROC: 	 last: 0.9850 	 max: 0.9850 	 epoch_max: 13
#
# Train epoch 14
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 14.0 	 train loss: -3.8001
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.88s/it]
# Epoch: 14.1 	 train loss: -3.7889
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 14.2 	 train loss: -3.7708
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 14.3 	 train loss: -3.7800
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 14.4 	 train loss: -3.8096
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 14.5 	 train loss: -3.8348
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 14.6 	 train loss: -3.8420
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 14.7 	 train loss: -3.8494
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.84s/it]
# Epoch: 14 	 test_loss: 18.2000
# AUROC: 	 last: 0.9881 	 max: 0.9881 	 epoch_max: 14
#
# Train epoch 15
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 15.0 	 train loss: -3.8577
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 15.1 	 train loss: -3.8503
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 15.2 	 train loss: -3.8085
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 15.3 	 train loss: -3.8397
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 15.4 	 train loss: -3.8425
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 15.5 	 train loss: -3.8440
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 15.6 	 train loss: -3.8638
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 15.7 	 train loss: -3.8765
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.83s/it]
# Epoch: 15 	 test_loss: 0.4182
# AUROC: 	 last: 0.9880 	 max: 0.9881 	 epoch_max: 14
#
# Train epoch 16
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 16.0 	 train loss: -3.8582
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 16.1 	 train loss: -3.8731
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 16.2 	 train loss: -3.8602
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.81s/it]
# Epoch: 16.3 	 train loss: -3.8497
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 16.4 	 train loss: -3.8354
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 16.5 	 train loss: -3.8796
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 16.6 	 train loss: -3.8852
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 16.7 	 train loss: -3.8890
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.84s/it]
# Epoch: 16 	 test_loss: 48.4710
# AUROC: 	 last: 0.9732 	 max: 0.9881 	 epoch_max: 14
#
# Train epoch 17
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 17.0 	 train loss: -3.9015
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.87s/it]
# Epoch: 17.1 	 train loss: -3.8423
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 17.2 	 train loss: -3.8874
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 17.3 	 train loss: -3.9036
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 17.4 	 train loss: -3.9023
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 17.5 	 train loss: -3.8799
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 17.6 	 train loss: -3.8986
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 17.7 	 train loss: -3.9062
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.84s/it]
# Epoch: 17 	 test_loss: 1.3340
# AUROC: 	 last: 0.9841 	 max: 0.9881 	 epoch_max: 14
#
# Train epoch 18
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 18.0 	 train loss: -3.9050
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 18.1 	 train loss: -3.9041
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 18.2 	 train loss: -3.9057
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 18.3 	 train loss: -3.9076
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 18.4 	 train loss: -3.9062
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 18.5 	 train loss: -3.9232
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.82s/it]
# Epoch: 18.6 	 train loss: -3.9065
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 18.7 	 train loss: -3.9055
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.84s/it]
# Epoch: 18 	 test_loss: 604.2537
# AUROC: 	 last: 0.9828 	 max: 0.9881 	 epoch_max: 14
#
# Train epoch 19
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 19.0 	 train loss: -3.9267
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 19.1 	 train loss: -3.9295
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.90s/it]
# Epoch: 19.2 	 train loss: -3.9356
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 19.3 	 train loss: -3.9349
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 19.4 	 train loss: -3.9232
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 19.5 	 train loss: -3.9392
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 19.6 	 train loss: -3.9324
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 19.7 	 train loss: -3.9368
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.80s/it]
# Epoch: 19 	 test_loss: 78.8470
# AUROC: 	 last: 0.9892 	 max: 0.9892 	 epoch_max: 19
#
# Train epoch 20
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 20.0 	 train loss: -3.9289
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 20.1 	 train loss: -3.8628
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 20.2 	 train loss: -3.9063
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.82s/it]
# Epoch: 20.3 	 train loss: -3.8683
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.92s/it]
# Epoch: 20.4 	 train loss: -3.9347
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 20.5 	 train loss: -3.9552
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 20.6 	 train loss: -3.9566
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 20.7 	 train loss: -3.9677
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:49<00:00,  2.81s/it]
# Epoch: 20 	 test_loss: 25.0444
# AUROC: 	 last: 0.9821 	 max: 0.9892 	 epoch_max: 19
#
# Train epoch 21
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 21.0 	 train loss: -3.9650
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 21.1 	 train loss: -3.9626
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.82s/it]
# Epoch: 21.2 	 train loss: -3.9501
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 21.3 	 train loss: -3.9675
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 21.4 	 train loss: -3.9569
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 21.5 	 train loss: -3.9572
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 21.6 	 train loss: -3.9672
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.82s/it]
# Epoch: 21.7 	 train loss: -3.9723
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.83s/it]
# Epoch: 21 	 test_loss: 1.7844
# AUROC: 	 last: 0.9897 	 max: 0.9897 	 epoch_max: 21
#
# Train epoch 22
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 22.0 	 train loss: -3.9845
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 22.1 	 train loss: -3.9600
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 22.2 	 train loss: -3.9709
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 22.3 	 train loss: -3.9675
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 22.4 	 train loss: -3.9840
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 22.5 	 train loss: -3.9645
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.83s/it]
# Epoch: 22.6 	 train loss: -3.9435
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 22.7 	 train loss: -3.9792
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.83s/it]
# Epoch: 22 	 test_loss: 1964.6238
# AUROC: 	 last: 0.9862 	 max: 0.9897 	 epoch_max: 21
#
# Train epoch 23
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 23.0 	 train loss: -3.9707
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.86s/it]
# Epoch: 23.1 	 train loss: -3.9896
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 23.2 	 train loss: -3.9955
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.95s/it]
# Epoch: 23.3 	 train loss: -3.9866
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 23.4 	 train loss: -3.9978
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Epoch: 23.5 	 train loss: -3.9923
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.84s/it]
# Epoch: 23.6 	 train loss: -3.9856
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.88s/it]
# Epoch: 23.7 	 train loss: -4.0092
#
# Compute loss and scores on test set:
# 100%|███████████████████████████████████████████| 39/39 [01:50<00:00,  2.83s/it]
# Epoch: 23 	 test_loss: 5.6864
# AUROC: 	 last: 0.9879 	 max: 0.9897 	 epoch_max: 21
# Training time for DAGM_class_4: 7553.65 seconds
#
# Training Summary:
# DAGM_class_1:
#   Model name: DAGM_model_DAGM_class_1
#   Training time: 7542.96 seconds
# DAGM_class_2:
#   Model name: DAGM_model_DAGM_class_2
#   Training time: 7366.13 seconds
# DAGM_class_3:
#   Model name: DAGM_model_DAGM_class_3
#   Training time: 7422.04 seconds
# DAGM_class_4:
#   Model name: DAGM_model_DAGM_class_4
#   Training time: 7553.65 seconds
#
# Total training time for all classes: 29884.79 seconds
